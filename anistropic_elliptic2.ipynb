# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import time

# ======================
# 1. 基本设置 (无变化)
# ======================
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 训练区域 [-1, 1]^2
lb = torch.tensor([-1.0, -1.0]).to(device)
ub = torch.tensor([1.0, 1.0]).to(device)

# 各向异性系数矩阵 A
A = torch.tensor([[1.0, 2.0],
                  [2.0, 5.0]], dtype=torch.float64).to(device)

# ======================
# 2. 精确解与右端项 (无变化)
# ======================
def u_exact(x, y):
    # 添加一个极小的 epsilon 防止 x,y 同时为 0 时出现 nan
    eps = 1e-8
    return (x**2 + y**2 + eps)**(2/3)

def f_exact(x, y):
    # 添加一个极小的 epsilon 防止 x,y 同时为 0 时出现 nan
    eps = 1e-8
    return 32 * (2*x**2 + y**2 - x*y) / (9 * (x**2 + y**2 + eps)**(4/3))

# ======================
# 3. PINN 网络结构 (修改)
# ======================
# 2. 简化网络结构: 减少层宽和层数，降低参数量，可能加速收敛
# 原网络: [2, 128, 128, 128, 1]
# 新网络: [2, 64, 64, 64, 1]
class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.layers = nn.ModuleList()
        for i in range(len(layers)-1):
            self.layers.append(nn.Linear(layers[i], layers[i+1]))
        self.activation = nn.Tanh()

    def forward(self, x):
        for i in range(len(self.layers)-1):
            x = self.activation(self.layers[i](x))
        return self.layers[-1](x)

# 网络配置
layers = [2, 64, 64, 64, 1]
model = MLP(layers).to(device)

# ======================
# 4. 物理残差定义 (无变化)
# ======================
def pde_residual(xy, model_instance):
    xy.requires_grad_(True)
    u = model_instance(xy)

    grads = torch.autograd.grad(u, xy, torch.ones_like(u), create_graph=True)[0]
    ux = grads[:, 0:1]
    uy = grads[:, 1:2]

    # A∇u
    Agrad = torch.cat([A[0,0]*ux + A[0,1]*uy,
                       A[1,0]*ux + A[1,1]*uy], dim=1)

    div_term = []
    for i in range(2):
        grad_Aui = torch.autograd.grad(Agrad[:, i], xy, torch.ones_like(Agrad[:, i]), create_graph=True)[0]
        div_term.append(grad_Aui[:, i:i+1])
    div_Agrad = sum(div_term)

    f_val = f_exact(xy[:, 0:1], xy[:, 1:2])
    return div_Agrad - f_val

# ======================
# 5. 采样点 (修改)
# ======================
# 3. 强化采样策略
def sample_interior_enhanced(n, epsilon=1e-4):
    """
    在内部采样，但在原点附近进行加密采样，同时严格避开奇点 (0,0)。
    - n_dense: 在半径为 r_dense 的小圆内密集采样的点数
    - n_sparse: 在剩余区域采样的点数
    """
    n_dense = int(n * 0.7)  # 70% 的点用于密集区域
    n_sparse = n - n_dense
    r_dense = 0.2 # 定义密集采样区域的半径

    # (1) 密集区域采样 (环形区域)
    # 在 [epsilon, r_dense] 内采样，避免奇点
    theta = 2 * np.pi * torch.rand(n_dense, 1, device=device, dtype=torch.float64)
    # 通过开方使r的分布更均匀地覆盖面积
    r = torch.sqrt(torch.rand(n_dense, 1, device=device, dtype=torch.float64) * (r_dense**2 - epsilon**2) + epsilon**2)
    x_dense = r * torch.cos(theta)
    y_dense = r * torch.sin(theta)
    xy_dense = torch.cat([x_dense, y_dense], dim=1)

    # (2) 稀疏区域采样 (矩形减去中心圆)
    xy_sparse = torch.zeros((n_sparse, 2), device=device, dtype=torch.float64)
    count = 0
    while count < n_sparse:
        # 在整个 [-1,1]^2 区域随机采样
        xy_candidate = lb + (ub - lb) * torch.rand(n_sparse, 2, device=device, dtype=torch.float64)
        # 计算到原点的距离
        dist_from_origin = torch.sqrt(xy_candidate[:,0]**2 + xy_candidate[:,1]**2)
        # 保留密集区域外的点
        mask = dist_from_origin > r_dense
        valid_points = xy_candidate[mask]

        num_valid = valid_points.shape[0]
        if num_valid > 0:
            take_num = min(num_valid, n_sparse - count)
            xy_sparse[count:count+take_num, :] = valid_points[:take_num, :]
            count += take_num

    return torch.cat([xy_dense, xy_sparse], dim=0)


def sample_boundary(n_per_edge):
    """
    在四条边上均匀采样，增加边界点数量以强化约束。
    """
    # top and bottom edges
    x_tb = torch.linspace(-1, 1, n_per_edge, device=device, dtype=torch.float64).view(-1, 1)
    y_top = torch.ones_like(x_tb)
    y_bottom = -torch.ones_like(x_tb)
    xy_top = torch.cat([x_tb, y_top], dim=1)
    xy_bottom = torch.cat([x_tb, y_bottom], dim=1)

    # left and right edges (excluding corners already included)
    y_lr = torch.linspace(-1, 1, n_per_edge, device=device, dtype=torch.float64)[1:-1].view(-1, 1)
    x_left = -torch.ones_like(y_lr)
    x_right = torch.ones_like(y_lr)
    xy_left = torch.cat([x_left, y_lr], dim=1)
    xy_right = torch.cat([x_right, y_lr], dim=1)

    xb = torch.cat([xy_top, xy_bottom, xy_left, xy_right], dim=0)
    ub_val = u_exact(xb[:,0:1], xb[:,1:2])
    return xb, ub_val

# ======================
# 6. 训练逻辑 (核心修改)
# ======================
# 采样点和权重
N_f = 4000  # 增加内部点
N_b_per_edge = 401 # 增加边界点, 总共 401*4 - 4 = 1600 个点
lambda_bc = 100.0

# ---- 第一阶段：Adam 优化 ----
print("--- Phase 1: Adam Optimization ---")
optimizer_adam = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer_adam, step_size=2000, gamma=0.5)
adam_epochs = 8000

# 预先采样固定的点用于 Adam 训练（也可以在循环内采样）
xy_f_adam = sample_interior_enhanced(N_f).to(device)
xy_b_adam, u_b_adam = sample_boundary(N_b_per_edge)
xy_b_adam, u_b_adam = xy_b_adam.to(device), u_b_adam.to(device)


for epoch in range(adam_epochs):
    optimizer_adam.zero_grad()

    res = pde_residual(xy_f_adam, model)
    loss_pde = torch.mean(res**2)

    u_pred_b = model(xy_b_adam)
    loss_bc = torch.mean((u_pred_b - u_b_adam)**2)

    loss = loss_pde + lambda_bc * loss_bc

    loss.backward()
    optimizer_adam.step()
    scheduler.step()

    if epoch % 500 == 0:
        print(f"Adam Epoch {epoch:5d} | Total Loss = {loss.item():.3e} | PDE loss = {loss_pde.item():.3e} | BC loss = {loss_bc.item():.3e}")

# ---- 第二阶段：L-BFGS 优化 ----
# 1. 实现 L-BFGS 优化器逻辑
print("\n--- Phase 2: L-BFGS Optimization ---")
optimizer_lbfgs = torch.optim.LBFGS(
    model.parameters(),
    lr=1.0,  # L-BFGS 的学习率通常设为 1
    max_iter=50000, # L-BFGS 自身的迭代次数
    max_eval=50000,
    history_size=50,
    line_search_fn="strong_wolfe"  # 使用强 Wolfe 线搜索
)

# L-BFGS 需要一个闭包函数，该函数重新计算损失并返回它
def closure():
    optimizer_lbfgs.zero_grad()

    # 在每个 L-BFGS 评估步骤中，可以使用相同的采样点
    # 或者重新采样以获得更好的泛化性。这里我们使用 Adam 训练后的点集。
    res = pde_residual(xy_f_adam, model)
    loss_pde = torch.mean(res**2)

    u_pred_b = model(xy_b_adam)
    loss_bc = torch.mean((u_pred_b - u_b_adam)**2)

    loss = loss_pde + lambda_bc * loss_bc

    loss.backward()

    # 打印 L-BFGS 内部的迭代信息
    global lbfgs_iter
    if lbfgs_iter % 100 == 0:
        print(f"L-BFGS Iter {lbfgs_iter:5d} | Total Loss = {loss.item():.3e} | PDE loss = {loss_pde.item():.3e} | BC loss = {loss_bc.item():.3e}")
    lbfgs_iter += 1

    return loss

# 4. 调用 L-BFGS 优化器
global lbfgs_iter
lbfgs_iter = 0
optimizer_lbfgs.step(closure)


# ======================
# 7. 可视化与误差计算 (无变化)
# ======================
print("\n--- Evaluating Final Model ---")
x = np.linspace(-1, 1, 201)
y = np.linspace(-1, 1, 201)
X, Y = np.meshgrid(x, y)
XY = torch.tensor(np.vstack((X.flatten(), Y.flatten())).T, dtype=torch.float64).to(device)

with torch.no_grad():
    U_pred = model(XY).cpu().numpy().reshape(X.shape)
    U_true_grid = u_exact(torch.from_numpy(X), torch.from_numpy(Y)).numpy()
    error = np.abs(U_pred - U_true_grid)

# 计算 L2 相对误差
l2_error = np.linalg.norm(U_pred - U_true_grid) / np.linalg.norm(U_true_grid)
print(f"Final Relative L2 Error: {l2_error:.3e}")


plt.figure(figsize=(16, 4.5))
plt.subplot(1, 3, 1)
plt.title("Predicted u")
plt.pcolormesh(X, Y, U_pred, shading='auto', cmap='jet')
plt.colorbar()
plt.xlabel("x")
plt.ylabel("y")
plt.axis('square')


plt.subplot(1, 3, 2)
plt.title("Exact u")
plt.pcolormesh(X, Y, U_true_grid, shading='auto', cmap='jet')
plt.colorbar()
plt.xlabel("x")
plt.ylabel("y")
plt.axis('square')


plt.subplot(1, 3, 3)
plt.title("Absolute Error")
plt.pcolormesh(X, Y, error, shading='auto', cmap='jet')
plt.colorbar()
plt.xlabel("x")
plt.ylabel("y")
plt.axis('square')


plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# --- Phase 1: Adam Optimization ---
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:829: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:179.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Adam Epoch     0 | Total Loss = 7.093e+02 | PDE loss = 5.693e+02 | BC loss = 1.400e+00
# Adam Epoch   500 | Total Loss = 5.541e+01 | PDE loss = 5.507e+01 | BC loss = 3.366e-03
# Adam Epoch  1000 | Total Loss = 3.615e+01 | PDE loss = 3.597e+01 | BC loss = 1.823e-03
# Adam Epoch  1500 | Total Loss = 2.987e+01 | PDE loss = 2.975e+01 | BC loss = 1.213e-03
# Adam Epoch  2000 | Total Loss = 2.048e+01 | PDE loss = 2.043e+01 | BC loss = 4.296e-04
# Adam Epoch  2500 | Total Loss = 1.728e+01 | PDE loss = 1.724e+01 | BC loss = 4.275e-04
# Adam Epoch  3000 | Total Loss = 1.416e+01 | PDE loss = 1.411e+01 | BC loss = 4.082e-04
# Adam Epoch  3500 | Total Loss = 1.227e+01 | PDE loss = 1.223e+01 | BC loss = 3.696e-04
# Adam Epoch  4000 | Total Loss = 8.789e+00 | PDE loss = 8.750e+00 | BC loss = 3.873e-04
# Adam Epoch  4500 | Total Loss = 6.768e+00 | PDE loss = 6.729e+00 | BC loss = 3.876e-04
# Adam Epoch  5000 | Total Loss = 5.489e+00 | PDE loss = 5.447e+00 | BC loss = 4.253e-04
# Adam Epoch  5500 | Total Loss = 4.770e+00 | PDE loss = 4.727e+00 | BC loss = 4.328e-04
# Adam Epoch  6000 | Total Loss = 3.487e+00 | PDE loss = 3.447e+00 | BC loss = 4.066e-04
# Adam Epoch  6500 | Total Loss = 3.112e+00 | PDE loss = 3.073e+00 | BC loss = 3.894e-04
# Adam Epoch  7000 | Total Loss = 2.715e+00 | PDE loss = 2.679e+00 | BC loss = 3.626e-04
# Adam Epoch  7500 | Total Loss = 2.348e+00 | PDE loss = 2.315e+00 | BC loss = 3.357e-04
#
# --- Phase 2: L-BFGS Optimization ---
# L-BFGS Iter     0 | Total Loss = 2.069e+00 | PDE loss = 2.037e+00 | BC loss = 3.118e-04
# L-BFGS Iter   100 | Total Loss = 1.987e+00 | PDE loss = 1.957e+00 | BC loss = 3.070e-04
# L-BFGS Iter   200 | Total Loss = 1.899e+00 | PDE loss = 1.870e+00 | BC loss = 2.887e-04
# L-BFGS Iter   300 | Total Loss = 1.779e+00 | PDE loss = 1.751e+00 | BC loss = 2.813e-04
# L-BFGS Iter   400 | Total Loss = 1.652e+00 | PDE loss = 1.624e+00 | BC loss = 2.805e-04
# L-BFGS Iter   500 | Total Loss = 1.505e+00 | PDE loss = 1.475e+00 | BC loss = 2.995e-04
# L-BFGS Iter   600 | Total Loss = 1.399e+00 | PDE loss = 1.375e+00 | BC loss = 2.362e-04
# L-BFGS Iter   700 | Total Loss = 1.303e+00 | PDE loss = 1.280e+00 | BC loss = 2.248e-04
# L-BFGS Iter   800 | Total Loss = 1.225e+00 | PDE loss = 1.203e+00 | BC loss = 2.253e-04
# L-BFGS Iter   900 | Total Loss = 1.167e+00 | PDE loss = 1.145e+00 | BC loss = 2.143e-04
# L-BFGS Iter  1000 | Total Loss = 1.109e+00 | PDE loss = 1.086e+00 | BC loss = 2.235e-04
# L-BFGS Iter  1100 | Total Loss = 1.058e+00 | PDE loss = 1.035e+00 | BC loss = 2.281e-04
# L-BFGS Iter  1200 | Total Loss = 9.983e-01 | PDE loss = 9.806e-01 | BC loss = 1.760e-04
# L-BFGS Iter  1300 | Total Loss = 9.371e-01 | PDE loss = 9.187e-01 | BC loss = 1.840e-04
# L-BFGS Iter  1400 | Total Loss = 8.963e-01 | PDE loss = 8.768e-01 | BC loss = 1.946e-04
# L-BFGS Iter  1500 | Total Loss = 8.474e-01 | PDE loss = 8.324e-01 | BC loss = 1.504e-04
# L-BFGS Iter  1600 | Total Loss = 7.971e-01 | PDE loss = 7.808e-01 | BC loss = 1.633e-04
# L-BFGS Iter  4300 | Total Loss = 2.955e-01 | PDE loss = 2.882e-01 | BC loss = 7.310e-05
# L-BFGS Iter  4400 | Total Loss = 2.875e-01 | PDE loss = 2.799e-01 | BC loss = 7.590e-05
# L-BFGS Iter  4500 | Total Loss = 2.800e-01 | PDE loss = 2.728e-01 | BC loss = 7.239e-05
# L-BFGS Iter  4600 | Total Loss = 2.732e-01 | PDE loss = 2.658e-01 | BC loss = 7.390e-05
# L-BFGS Iter  4700 | Total Loss = 2.675e-01 | PDE loss = 2.599e-01 | BC loss = 7.562e-05
# L-BFGS Iter  4800 | Total Loss = 2.609e-01 | PDE loss = 2.526e-01 | BC loss = 8.270e-05
# L-BFGS Iter  4900 | Total Loss = 2.550e-01 | PDE loss = 2.462e-01 | BC loss = 8.773e-05
# L-BFGS Iter  5000 | Total Loss = 2.495e-01 | PDE loss = 2.401e-01 | BC loss = 9.355e-05
# L-BFGS Iter  5100 | Total Loss = 2.443e-01 | PDE loss = 2.346e-01 | BC loss = 9.661e-05
# L-BFGS Iter  5200 | Total Loss = 2.399e-01 | PDE loss = 2.301e-01 | BC loss = 9.790e-05
# L-BFGS Iter  5300 | Total Loss = 2.351e-01 | PDE loss = 2.250e-01 | BC loss = 1.012e-04
# L-BFGS Iter  5400 | Total Loss = 2.301e-01 | PDE loss = 2.200e-01 | BC loss = 1.008e-04
# L-BFGS Iter  5500 | Total Loss = 2.257e-01 | PDE loss = 2.158e-01 | BC loss = 9.914e-05
# L-BFGS Iter  5600 | Total Loss = 2.212e-01 | PDE loss = 2.120e-01 | BC loss = 9.252e-05
# L-BFGS Iter  5700 | Total Loss = 2.175e-01 | PDE loss = 2.085e-01 | BC loss = 8.968e-05
# L-BFGS Iter  5800 | Total Loss = 2.144e-01 | PDE loss = 2.056e-01 | BC loss = 8.860e-05
# L-BFGS Iter  5900 | Total Loss = 2.110e-01 | PDE loss = 2.023e-01 | BC loss = 8.660e-05
# L-BFGS Iter  6000 | Total Loss = 2.068e-01 | PDE loss = 1.985e-01 | BC loss = 8.330e-05
# L-BFGS Iter  6100 | Total Loss = 2.020e-01 | PDE loss = 1.940e-01 | BC loss = 8.018e-05
# L-BFGS Iter  6200 | Total Loss = 1.983e-01 | PDE loss = 1.903e-01 | BC loss = 8.020e-05
# L-BFGS Iter  6300 | Total Loss = 1.954e-01 | PDE loss = 1.876e-01 | BC loss = 7.799e-05
# L-BFGS Iter  6400 | Total Loss = 1.914e-01 | PDE loss = 1.839e-01 | BC loss = 7.567e-05
# L-BFGS Iter  6500 | Total Loss = 1.875e-01 | PDE loss = 1.804e-01 | BC loss = 7.159e-05
# L-BFGS Iter  6600 | Total Loss = 1.843e-01 | PDE loss = 1.773e-01 | BC loss = 6.970e-05
# L-BFGS Iter  6700 | Total Loss = 1.806e-01 | PDE loss = 1.737e-01 | BC loss = 6.860e-05
# L-BFGS Iter  6800 | Total Loss = 1.770e-01 | PDE loss = 1.702e-01 | BC loss = 6.868e-05
# L-BFGS Iter  6900 | Total Loss = 1.745e-01 | PDE loss = 1.677e-01 | BC loss = 6.831e-05
# L-BFGS Iter  7000 | Total Loss = 1.711e-01 | PDE loss = 1.644e-01 | BC loss = 6.780e-05
# L-BFGS Iter  7100 | Total Loss = 1.680e-01 | PDE loss = 1.613e-01 | BC loss = 6.695e-05
# L-BFGS Iter  7200 | Total Loss = 1.657e-01 | PDE loss = 1.589e-01 | BC loss = 6.771e-05
# L-BFGS Iter  7300 | Total Loss = 1.629e-01 | PDE loss = 1.560e-01 | BC loss = 6.892e-05
# L-BFGS Iter  7400 | Total Loss = 1.611e-01 | PDE loss = 1.542e-01 | BC loss = 6.939e-05
# L-BFGS Iter  7500 | Total Loss = 1.588e-01 | PDE loss = 1.521e-01 | BC loss = 6.668e-05
# L-BFGS Iter  7600 | Total Loss = 1.564e-01 | PDE loss = 1.499e-01 | BC loss = 6.502e-05
# L-BFGS Iter  7700 | Total Loss = 1.540e-01 | PDE loss = 1.478e-01 | BC loss = 6.246e-05
# L-BFGS Iter  7800 | Total Loss = 1.513e-01 | PDE loss = 1.455e-01 | BC loss = 5.855e-05
# L-BFGS Iter  7900 | Total Loss = 1.484e-01 | PDE loss = 1.431e-01 | BC loss = 5.364e-05
# L-BFGS Iter  8000 | Total Loss = 1.455e-01 | PDE loss = 1.405e-01 | BC loss = 5.047e-05
# L-BFGS Iter  8100 | Total Loss = 1.434e-01 | PDE loss = 1.384e-01 | BC loss = 4.934e-05
# L-BFGS Iter  8200 | Total Loss = 1.411e-01 | PDE loss = 1.364e-01 | BC loss = 4.679e-05
# L-BFGS Iter  8300 | Total Loss = 1.383e-01 | PDE loss = 1.339e-01 | BC loss = 4.458e-05
# L-BFGS Iter  8400 | Total Loss = 1.361e-01 | PDE loss = 1.320e-01 | BC loss = 4.099e-05
# L-BFGS Iter  8500 | Total Loss = 1.340e-01 | PDE loss = 1.302e-01 | BC loss = 3.823e-05
# L-BFGS Iter  8600 | Total Loss = 1.313e-01 | PDE loss = 1.276e-01 | BC loss = 3.681e-05
# L-BFGS Iter  8700 | Total Loss = 1.295e-01 | PDE loss = 1.260e-01 | BC loss = 3.532e-05
# L-BFGS Iter  8800 | Total Loss = 1.280e-01 | PDE loss = 1.245e-01 | BC loss = 3.451e-05
# L-BFGS Iter  8900 | Total Loss = 1.259e-01 | PDE loss = 1.226e-01 | BC loss = 3.242e-05
# L-BFGS Iter  9000 | Total Loss = 1.240e-01 | PDE loss = 1.208e-01 | BC loss = 3.128e-05
# L-BFGS Iter  9100 | Total Loss = 1.222e-01 | PDE loss = 1.190e-01 | BC loss = 3.244e-05
# L-BFGS Iter  9200 | Total Loss = 1.207e-01 | PDE loss = 1.175e-01 | BC loss = 3.220e-05
# L-BFGS Iter  9300 | Total Loss = 1.190e-01 | PDE loss = 1.157e-01 | BC loss = 3.297e-05
# L-BFGS Iter  9400 | Total Loss = 1.174e-01 | PDE loss = 1.141e-01 | BC loss = 3.273e-05
# L-BFGS Iter  9500 | Total Loss = 1.155e-01 | PDE loss = 1.124e-01 | BC loss = 3.156e-05
# L-BFGS Iter  9600 | Total Loss = 1.141e-01 | PDE loss = 1.110e-01 | BC loss = 3.116e-05
# L-BFGS Iter  9700 | Total Loss = 1.126e-01 | PDE loss = 1.095e-01 | BC loss = 3.048e-05
# L-BFGS Iter  9800 | Total Loss = 1.114e-01 | PDE loss = 1.084e-01 | BC loss = 3.083e-05
# L-BFGS Iter  9900 | Total Loss = 1.094e-01 | PDE loss = 1.064e-01 | BC loss = 3.064e-05
# L-BFGS Iter 10000 | Total Loss = 1.079e-01 | PDE loss = 1.049e-01 | BC loss = 3.020e-05
# L-BFGS Iter 10100 | Total Loss = 1.064e-01 | PDE loss = 1.034e-01 | BC loss = 3.037e-05
# L-BFGS Iter 10200 | Total Loss = 1.042e-01 | PDE loss = 1.012e-01 | BC loss = 2.934e-05
# L-BFGS Iter 10300 | Total Loss = 1.024e-01 | PDE loss = 9.965e-02 | BC loss = 2.704e-05
# L-BFGS Iter 10400 | Total Loss = 1.005e-01 | PDE loss = 9.803e-02 | BC loss = 2.444e-05
# L-BFGS Iter 10500 | Total Loss = 9.797e-02 | PDE loss = 9.566e-02 | BC loss = 2.313e-05
# L-BFGS Iter 10600 | Total Loss = 9.969e-02 | PDE loss = 9.713e-02 | BC loss = 2.556e-05
# L-BFGS Iter 10700 | Total Loss = 9.425e-02 | PDE loss = 9.197e-02 | BC loss = 2.279e-05
# L-BFGS Iter 10800 | Total Loss = 9.274e-02 | PDE loss = 9.041e-02 | BC loss = 2.331e-05
# L-BFGS Iter 10900 | Total Loss = 9.101e-02 | PDE loss = 8.867e-02 | BC loss = 2.347e-05
# L-BFGS Iter 11000 | Total Loss = 8.909e-02 | PDE loss = 8.679e-02 | BC loss = 2.298e-05
# L-BFGS Iter 11100 | Total Loss = 8.674e-02 | PDE loss = 8.440e-02 | BC loss = 2.338e-05
# L-BFGS Iter 11200 | Total Loss = 8.522e-02 | PDE loss = 8.288e-02 | BC loss = 2.349e-05
# L-BFGS Iter 11300 | Total Loss = 8.372e-02 | PDE loss = 8.140e-02 | BC loss = 2.324e-05
# L-BFGS Iter 11400 | Total Loss = 8.257e-02 | PDE loss = 8.022e-02 | BC loss = 2.343e-05
# L-BFGS Iter 11500 | Total Loss = 8.100e-02 | PDE loss = 7.866e-02 | BC loss = 2.340e-05
# L-BFGS Iter 11600 | Total Loss = 7.990e-02 | PDE loss = 7.751e-02 | BC loss = 2.393e-05
# L-BFGS Iter 11700 | Total Loss = 7.903e-02 | PDE loss = 7.666e-02 | BC loss = 2.373e-05
# L-BFGS Iter 11800 | Total Loss = 7.750e-02 | PDE loss = 7.516e-02 | BC loss = 2.337e-05
# L-BFGS Iter 11900 | Total Loss = 7.649e-02 | PDE loss = 7.409e-02 | BC loss = 2.400e-05
# L-BFGS Iter 12000 | Total Loss = 7.544e-02 | PDE loss = 7.309e-02 | BC loss = 2.354e-05
# L-BFGS Iter 12100 | Total Loss = 7.438e-02 | PDE loss = 7.207e-02 | BC loss = 2.309e-05
# L-BFGS Iter 12200 | Total Loss = 7.329e-02 | PDE loss = 7.115e-02 | BC loss = 2.138e-05
# L-BFGS Iter 12300 | Total Loss = 7.210e-02 | PDE loss = 7.002e-02 | BC loss = 2.076e-05
# L-BFGS Iter 33900 | Total Loss = 1.116e-02 | PDE loss = 1.098e-02 | BC loss = 1.881e-06
# L-BFGS Iter 34000 | Total Loss = 1.112e-02 | PDE loss = 1.094e-02 | BC loss = 1.878e-06
# L-BFGS Iter 34100 | Total Loss = 1.108e-02 | PDE loss = 1.090e-02 | BC loss = 1.851e-06
# L-BFGS Iter 34200 | Total Loss = 1.101e-02 | PDE loss = 1.083e-02 | BC loss = 1.804e-06
# L-BFGS Iter 34300 | Total Loss = 1.093e-02 | PDE loss = 1.076e-02 | BC loss = 1.687e-06
# L-BFGS Iter 34400 | Total Loss = 1.088e-02 | PDE loss = 1.072e-02 | BC loss = 1.626e-06
# L-BFGS Iter 34500 | Total Loss = 1.082e-02 | PDE loss = 1.066e-02 | BC loss = 1.567e-06
# L-BFGS Iter 34600 | Total Loss = 1.076e-02 | PDE loss = 1.061e-02 | BC loss = 1.547e-06
# L-BFGS Iter 34700 | Total Loss = 1.070e-02 | PDE loss = 1.055e-02 | BC loss = 1.528e-06
# L-BFGS Iter 34800 | Total Loss = 1.059e-02 | PDE loss = 1.044e-02 | BC loss = 1.494e-06
# L-BFGS Iter 34900 | Total Loss = 1.047e-02 | PDE loss = 1.033e-02 | BC loss = 1.489e-06
# L-BFGS Iter 35000 | Total Loss = 1.039e-02 | PDE loss = 1.024e-02 | BC loss = 1.451e-06
# L-BFGS Iter 35100 | Total Loss = 1.032e-02 | PDE loss = 1.018e-02 | BC loss = 1.411e-06
# L-BFGS Iter 35200 | Total Loss = 1.026e-02 | PDE loss = 1.013e-02 | BC loss = 1.352e-06
# L-BFGS Iter 35300 | Total Loss = 1.019e-02 | PDE loss = 1.006e-02 | BC loss = 1.310e-06
# L-BFGS Iter 35400 | Total Loss = 1.012e-02 | PDE loss = 9.995e-03 | BC loss = 1.273e-06
# L-BFGS Iter 35500 | Total Loss = 1.007e-02 | PDE loss = 9.945e-03 | BC loss = 1.238e-06
# L-BFGS Iter 35600 | Total Loss = 9.997e-03 | PDE loss = 9.874e-03 | BC loss = 1.226e-06
# L-BFGS Iter 35700 | Total Loss = 9.931e-03 | PDE loss = 9.811e-03 | BC loss = 1.203e-06
# L-BFGS Iter 35800 | Total Loss = 9.892e-03 | PDE loss = 9.770e-03 | BC loss = 1.217e-06
# L-BFGS Iter 35900 | Total Loss = 9.846e-03 | PDE loss = 9.725e-03 | BC loss = 1.206e-06
# L-BFGS Iter 36000 | Total Loss = 9.807e-03 | PDE loss = 9.688e-03 | BC loss = 1.189e-06
# L-BFGS Iter 36100 | Total Loss = 9.754e-03 | PDE loss = 9.638e-03 | BC loss = 1.161e-06
# L-BFGS Iter 36200 | Total Loss = 9.705e-03 | PDE loss = 9.592e-03 | BC loss = 1.128e-06
# L-BFGS Iter 36300 | Total Loss = 9.649e-03 | PDE loss = 9.540e-03 | BC loss = 1.085e-06
# L-BFGS Iter 36400 | Total Loss = 9.576e-03 | PDE loss = 9.467e-03 | BC loss = 1.092e-06
# L-BFGS Iter 36500 | Total Loss = 9.529e-03 | PDE loss = 9.419e-03 | BC loss = 1.100e-06
# L-BFGS Iter 36600 | Total Loss = 9.478e-03 | PDE loss = 9.368e-03 | BC loss = 1.105e-06
# L-BFGS Iter 36700 | Total Loss = 9.448e-03 | PDE loss = 9.337e-03 | BC loss = 1.112e-06
# L-BFGS Iter 36800 | Total Loss = 9.399e-03 | PDE loss = 9.287e-03 | BC loss = 1.126e-06
# L-BFGS Iter 36900 | Total Loss = 9.353e-03 | PDE loss = 9.239e-03 | BC loss = 1.142e-06
# L-BFGS Iter 37000 | Total Loss = 9.304e-03 | PDE loss = 9.188e-03 | BC loss = 1.160e-06
# L-BFGS Iter 37100 | Total Loss = 9.246e-03 | PDE loss = 9.130e-03 | BC loss = 1.156e-06
# L-BFGS Iter 37200 | Total Loss = 9.193e-03 | PDE loss = 9.080e-03 | BC loss = 1.131e-06
# L-BFGS Iter 37300 | Total Loss = 9.124e-03 | PDE loss = 9.018e-03 | BC loss = 1.062e-06
# L-BFGS Iter 37400 | Total Loss = 9.071e-03 | PDE loss = 8.969e-03 | BC loss = 1.022e-06
# L-BFGS Iter 37500 | Total Loss = 9.007e-03 | PDE loss = 8.906e-03 | BC loss = 1.010e-06
# L-BFGS Iter 37600 | Total Loss = 8.914e-03 | PDE loss = 8.809e-03 | BC loss = 1.057e-06
# L-BFGS Iter 37700 | Total Loss = 8.842e-03 | PDE loss = 8.731e-03 | BC loss = 1.117e-06
# L-BFGS Iter 37800 | Total Loss = 8.781e-03 | PDE loss = 8.662e-03 | BC loss = 1.189e-06
# L-BFGS Iter 37900 | Total Loss = 8.724e-03 | PDE loss = 8.603e-03 | BC loss = 1.215e-06
# L-BFGS Iter 38000 | Total Loss = 8.659e-03 | PDE loss = 8.542e-03 | BC loss = 1.172e-06
# L-BFGS Iter 38100 | Total Loss = 8.614e-03 | PDE loss = 8.497e-03 | BC loss = 1.162e-06
# L-BFGS Iter 38200 | Total Loss = 8.568e-03 | PDE loss = 8.451e-03 | BC loss = 1.167e-06
# L-BFGS Iter 38300 | Total Loss = 8.525e-03 | PDE loss = 8.410e-03 | BC loss = 1.152e-06
# L-BFGS Iter 38400 | Total Loss = 8.468e-03 | PDE loss = 8.349e-03 | BC loss = 1.187e-06
# L-BFGS Iter 38500 | Total Loss = 8.410e-03 | PDE loss = 8.287e-03 | BC loss = 1.229e-06
# L-BFGS Iter 38600 | Total Loss = 8.365e-03 | PDE loss = 8.241e-03 | BC loss = 1.247e-06
# L-BFGS Iter 38700 | Total Loss = 8.315e-03 | PDE loss = 8.193e-03 | BC loss = 1.223e-06
# L-BFGS Iter 38800 | Total Loss = 8.263e-03 | PDE loss = 8.144e-03 | BC loss = 1.197e-06
# L-BFGS Iter 38900 | Total Loss = 8.229e-03 | PDE loss = 8.114e-03 | BC loss = 1.145e-06
# L-BFGS Iter 39000 | Total Loss = 8.191e-03 | PDE loss = 8.078e-03 | BC loss = 1.127e-06
# L-BFGS Iter 39100 | Total Loss = 8.151e-03 | PDE loss = 8.040e-03 | BC loss = 1.111e-06
# L-BFGS Iter 39200 | Total Loss = 8.112e-03 | PDE loss = 8.003e-03 | BC loss = 1.086e-06
# L-BFGS Iter 39300 | Total Loss = 8.057e-03 | PDE loss = 7.947e-03 | BC loss = 1.095e-06
# L-BFGS Iter 39400 | Total Loss = 8.016e-03 | PDE loss = 7.907e-03 | BC loss = 1.090e-06
# L-BFGS Iter 39500 | Total Loss = 7.981e-03 | PDE loss = 7.872e-03 | BC loss = 1.090e-06
# L-BFGS Iter 39600 | Total Loss = 7.954e-03 | PDE loss = 7.844e-03 | BC loss = 1.092e-06
# L-BFGS Iter 39700 | Total Loss = 7.920e-03 | PDE loss = 7.811e-03 | BC loss = 1.085e-06
# L-BFGS Iter 39800 | Total Loss = 7.890e-03 | PDE loss = 7.781e-03 | BC loss = 1.088e-06
# L-BFGS Iter 39900 | Total Loss = 7.862e-03 | PDE loss = 7.754e-03 | BC loss = 1.076e-06
# L-BFGS Iter 40000 | Total Loss = 7.831e-03 | PDE loss = 7.724e-03 | BC loss = 1.071e-06
# L-BFGS Iter 40100 | Total Loss = 7.802e-03 | PDE loss = 7.697e-03 | BC loss = 1.056e-06
# L-BFGS Iter 40200 | Total Loss = 7.761e-03 | PDE loss = 7.654e-03 | BC loss = 1.067e-06
# L-BFGS Iter 40300 | Total Loss = 7.731e-03 | PDE loss = 7.624e-03 | BC loss = 1.074e-06
# L-BFGS Iter 40400 | Total Loss = 7.699e-03 | PDE loss = 7.590e-03 | BC loss = 1.090e-06
# L-BFGS Iter 40500 | Total Loss = 7.669e-03 | PDE loss = 7.555e-03 | BC loss = 1.132e-06
# L-BFGS Iter 40600 | Total Loss = 7.633e-03 | PDE loss = 7.519e-03 | BC loss = 1.137e-06
# L-BFGS Iter 40700 | Total Loss = 7.599e-03 | PDE loss = 7.484e-03 | BC loss = 1.157e-06
# L-BFGS Iter 40800 | Total Loss = 7.572e-03 | PDE loss = 7.455e-03 | BC loss = 1.164e-06
# L-BFGS Iter 40900 | Total Loss = 7.533e-03 | PDE loss = 7.417e-03 | BC loss = 1.166e-06
# L-BFGS Iter 41000 | Total Loss = 7.499e-03 | PDE loss = 7.390e-03 | BC loss = 1.092e-06
# L-BFGS Iter 41100 | Total Loss = 7.472e-03 | PDE loss = 7.366e-03 | BC loss = 1.066e-06
# L-BFGS Iter 41200 | Total Loss = 7.425e-03 | PDE loss = 7.322e-03 | BC loss = 1.030e-06
# L-BFGS Iter 41300 | Total Loss = 7.399e-03 | PDE loss = 7.298e-03 | BC loss = 1.009e-06
# L-BFGS Iter 41400 | Total Loss = 7.365e-03 | PDE loss = 7.265e-03 | BC loss = 1.000e-06
# L-BFGS Iter 41500 | Total Loss = 7.337e-03 | PDE loss = 7.237e-03 | BC loss = 9.958e-07
# L-BFGS Iter 41600 | Total Loss = 7.302e-03 | PDE loss = 7.202e-03 | BC loss = 9.976e-07
# L-BFGS Iter 41700 | Total Loss = 7.251e-03 | PDE loss = 7.154e-03 | BC loss = 9.627e-07
# L-BFGS Iter 41800 | Total Loss = 7.216e-03 | PDE loss = 7.122e-03 | BC loss = 9.379e-07
# L-BFGS Iter 41900 | Total Loss = 7.182e-03 | PDE loss = 7.093e-03 | BC loss = 8.923e-07
# L-BFGS Iter 42000 | Total Loss = 7.142e-03 | PDE loss = 7.055e-03 | BC loss = 8.683e-07
# L-BFGS Iter 42100 | Total Loss = 7.107e-03 | PDE loss = 7.019e-03 | BC loss = 8.787e-07
# L-BFGS Iter 42200 | Total Loss = 7.066e-03 | PDE loss = 6.976e-03 | BC loss = 8.948e-07
# L-BFGS Iter 42300 | Total Loss = 7.028e-03 | PDE loss = 6.938e-03 | BC loss = 8.958e-07
# L-BFGS Iter 42400 | Total Loss = 6.990e-03 | PDE loss = 6.898e-03 | BC loss = 9.217e-07
# L-BFGS Iter 42500 | Total Loss = 6.945e-03 | PDE loss = 6.849e-03 | BC loss = 9.660e-07
# L-BFGS Iter 42600 | Total Loss = 6.905e-03 | PDE loss = 6.807e-03 | BC loss = 9.779e-07
# L-BFGS Iter 42700 | Total Loss = 6.866e-03 | PDE loss = 6.768e-03 | BC loss = 9.744e-07
# L-BFGS Iter 42800 | Total Loss = 6.833e-03 | PDE loss = 6.738e-03 | BC loss = 9.504e-07
# L-BFGS Iter 42900 | Total Loss = 6.811e-03 | PDE loss = 6.718e-03 | BC loss = 9.256e-07
# L-BFGS Iter 43000 | Total Loss = 6.783e-03 | PDE loss = 6.693e-03 | BC loss = 9.003e-07
# L-BFGS Iter 43100 | Total Loss = 6.757e-03 | PDE loss = 6.669e-03 | BC loss = 8.831e-07
# L-BFGS Iter 43200 | Total Loss = 6.724e-03 | PDE loss = 6.636e-03 | BC loss = 8.819e-07
# L-BFGS Iter 43300 | Total Loss = 6.696e-03 | PDE loss = 6.605e-03 | BC loss = 9.067e-07
# L-BFGS Iter 43400 | Total Loss = 6.666e-03 | PDE loss = 6.575e-03 | BC loss = 9.058e-07
# L-BFGS Iter 43500 | Total Loss = 6.638e-03 | PDE loss = 6.547e-03 | BC loss = 9.011e-07
# L-BFGS Iter 43600 | Total Loss = 6.612e-03 | PDE loss = 6.521e-03 | BC loss = 9.089e-07
# L-BFGS Iter 43700 | Total Loss = 6.582e-03 | PDE loss = 6.490e-03 | BC loss = 9.211e-07
# L-BFGS Iter 43800 | Total Loss = 6.560e-03 | PDE loss = 6.466e-03 | BC loss = 9.475e-07
# L-BFGS Iter 43900 | Total Loss = 6.538e-03 | PDE loss = 6.440e-03 | BC loss = 9.754e-07
# L-BFGS Iter 44000 | Total Loss = 6.495e-03 | PDE loss = 6.395e-03 | BC loss = 9.981e-07
# L-BFGS Iter 44100 | Total Loss = 6.455e-03 | PDE loss = 6.359e-03 | BC loss = 9.675e-07
# L-BFGS Iter 44200 | Total Loss = 6.415e-03 | PDE loss = 6.318e-03 | BC loss = 9.766e-07
# L-BFGS Iter 44300 | Total Loss = 6.384e-03 | PDE loss = 6.286e-03 | BC loss = 9.822e-07
# L-BFGS Iter 44400 | Total Loss = 6.353e-03 | PDE loss = 6.255e-03 | BC loss = 9.774e-07
# L-BFGS Iter 44500 | Total Loss = 6.314e-03 | PDE loss = 6.219e-03 | BC loss = 9.494e-07
# L-BFGS Iter 44600 | Total Loss = 6.282e-03 | PDE loss = 6.186e-03 | BC loss = 9.571e-07
# L-BFGS Iter 44700 | Total Loss = 6.258e-03 | PDE loss = 6.162e-03 | BC loss = 9.545e-07
# L-BFGS Iter 44800 | Total Loss = 6.231e-03 | PDE loss = 6.136e-03 | BC loss = 9.526e-07
# L-BFGS Iter 44900 | Total Loss = 6.209e-03 | PDE loss = 6.114e-03 | BC loss = 9.555e-07
# L-BFGS Iter 45000 | Total Loss = 6.186e-03 | PDE loss = 6.088e-03 | BC loss = 9.778e-07
# L-BFGS Iter 45100 | Total Loss = 6.183e-03 | PDE loss = 6.088e-03 | BC loss = 9.556e-07
# L-BFGS Iter 45200 | Total Loss = 6.131e-03 | PDE loss = 6.036e-03 | BC loss = 9.435e-07
# L-BFGS Iter 45300 | Total Loss = 6.109e-03 | PDE loss = 6.012e-03 | BC loss = 9.672e-07
# L-BFGS Iter 45400 | Total Loss = 6.087e-03 | PDE loss = 5.991e-03 | BC loss = 9.596e-07
# L-BFGS Iter 45500 | Total Loss = 6.061e-03 | PDE loss = 5.961e-03 | BC loss = 1.000e-06
# L-BFGS Iter 45600 | Total Loss = 6.030e-03 | PDE loss = 5.929e-03 | BC loss = 1.015e-06
# L-BFGS Iter 45700 | Total Loss = 5.999e-03 | PDE loss = 5.898e-03 | BC loss = 1.003e-06
# L-BFGS Iter 45800 | Total Loss = 5.979e-03 | PDE loss = 5.877e-03 | BC loss = 1.014e-06
# L-BFGS Iter 45900 | Total Loss = 5.960e-03 | PDE loss = 5.858e-03 | BC loss = 1.019e-06
# L-BFGS Iter 46000 | Total Loss = 5.940e-03 | PDE loss = 5.839e-03 | BC loss = 1.017e-06
# L-BFGS Iter 46100 | Total Loss = 5.920e-03 | PDE loss = 5.820e-03 | BC loss = 1.004e-06
# L-BFGS Iter 46200 | Total Loss = 5.897e-03 | PDE loss = 5.798e-03 | BC loss = 9.880e-07
# L-BFGS Iter 46300 | Total Loss = 5.878e-03 | PDE loss = 5.782e-03 | BC loss = 9.683e-07
# L-BFGS Iter 46400 | Total Loss = 5.860e-03 | PDE loss = 5.763e-03 | BC loss = 9.691e-07
# L-BFGS Iter 46500 | Total Loss = 5.839e-03 | PDE loss = 5.744e-03 | BC loss = 9.529e-07
# L-BFGS Iter 46600 | Total Loss = 5.821e-03 | PDE loss = 5.727e-03 | BC loss = 9.399e-07
# L-BFGS Iter 46700 | Total Loss = 5.802e-03 | PDE loss = 5.709e-03 | BC loss = 9.294e-07
# L-BFGS Iter 46800 | Total Loss = 5.786e-03 | PDE loss = 5.694e-03 | BC loss = 9.207e-07
# L-BFGS Iter 46900 | Total Loss = 5.764e-03 | PDE loss = 5.672e-03 | BC loss = 9.187e-07
# L-BFGS Iter 47000 | Total Loss = 5.739e-03 | PDE loss = 5.649e-03 | BC loss = 9.009e-07
# L-BFGS Iter 47100 | Total Loss = 5.714e-03 | PDE loss = 5.627e-03 | BC loss = 8.763e-07
# L-BFGS Iter 47200 | Total Loss = 5.695e-03 | PDE loss = 5.609e-03 | BC loss = 8.631e-07
# L-BFGS Iter 47300 | Total Loss = 5.673e-03 | PDE loss = 5.587e-03 | BC loss = 8.586e-07
# L-BFGS Iter 47400 | Total Loss = 5.656e-03 | PDE loss = 5.571e-03 | BC loss = 8.488e-07
# L-BFGS Iter 47500 | Total Loss = 5.638e-03 | PDE loss = 5.554e-03 | BC loss = 8.372e-07
# L-BFGS Iter 47600 | Total Loss = 5.616e-03 | PDE loss = 5.532e-03 | BC loss = 8.386e-07
# L-BFGS Iter 47700 | Total Loss = 5.594e-03 | PDE loss = 5.510e-03 | BC loss = 8.379e-07
# L-BFGS Iter 47800 | Total Loss = 5.571e-03 | PDE loss = 5.486e-03 | BC loss = 8.482e-07
# L-BFGS Iter 47900 | Total Loss = 5.549e-03 | PDE loss = 5.463e-03 | BC loss = 8.596e-07
# L-BFGS Iter 48000 | Total Loss = 5.528e-03 | PDE loss = 5.441e-03 | BC loss = 8.631e-07
# L-BFGS Iter 48100 | Total Loss = 5.499e-03 | PDE loss = 5.413e-03 | BC loss = 8.632e-07
# L-BFGS Iter 48200 | Total Loss = 5.476e-03 | PDE loss = 5.391e-03 | BC loss = 8.536e-07
# L-BFGS Iter 48300 | Total Loss = 5.444e-03 | PDE loss = 5.359e-03 | BC loss = 8.454e-07
# L-BFGS Iter 48400 | Total Loss = 5.422e-03 | PDE loss = 5.339e-03 | BC loss = 8.267e-07
# L-BFGS Iter 48500 | Total Loss = 5.401e-03 | PDE loss = 5.319e-03 | BC loss = 8.223e-07
# L-BFGS Iter 48600 | Total Loss = 5.382e-03 | PDE loss = 5.302e-03 | BC loss = 8.049e-07
# L-BFGS Iter 48700 | Total Loss = 5.357e-03 | PDE loss = 5.277e-03 | BC loss = 7.961e-07
# L-BFGS Iter 48800 | Total Loss = 5.326e-03 | PDE loss = 5.244e-03 | BC loss = 8.143e-07
# L-BFGS Iter 48900 | Total Loss = 5.299e-03 | PDE loss = 5.216e-03 | BC loss = 8.254e-07
# L-BFGS Iter 49000 | Total Loss = 5.273e-03 | PDE loss = 5.189e-03 | BC loss = 8.421e-07
# L-BFGS Iter 49100 | Total Loss = 5.257e-03 | PDE loss = 5.171e-03 | BC loss = 8.573e-07
# L-BFGS Iter 49200 | Total Loss = 5.236e-03 | PDE loss = 5.148e-03 | BC loss = 8.833e-07
# L-BFGS Iter 49300 | Total Loss = 5.220e-03 | PDE loss = 5.131e-03 | BC loss = 8.933e-07
# L-BFGS Iter 49400 | Total Loss = 5.519e-03 | PDE loss = 5.418e-03 | BC loss = 1.007e-06
# L-BFGS Iter 49500 | Total Loss = 5.172e-03 | PDE loss = 5.084e-03 | BC loss = 8.825e-07
# L-BFGS Iter 49600 | Total Loss = 5.146e-03 | PDE loss = 5.057e-03 | BC loss = 8.897e-07
# L-BFGS Iter 49700 | Total Loss = 5.130e-03 | PDE loss = 5.041e-03 | BC loss = 8.883e-07
# L-BFGS Iter 49800 | Total Loss = 5.115e-03 | PDE loss = 5.025e-03 | BC loss = 8.913e-07
# L-BFGS Iter 49900 | Total Loss = 5.094e-03 | PDE loss = 5.005e-03 | BC loss = 8.909e-07
#
# --- Evaluating Final Model ---
# Final Relative L2 Error: 1.293e-03
